# %%
from pylab import *
from rtlsdr import *
from numpy import linspace, concatenate, array, cumsum, insert, mean
from math import ceil, floor

# %%
sdr = RtlSdr()

# configure device
sdr.sample_rate = 1e6
sdr.center_freq = 92.3e6
sdr.freq_correction = 1
sdr.gain = 1

samples = sdr.read_samples(1024*1024*6)
sdr.close()

Fs = sdr.sample_rate/1e6
Fc = sdr.center_freq/1e6
NFFT = 1024

psd(samples, NFFT=NFFT, Fs=Fs, Fc=Fc)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
show()

# %%
sdr = RtlSdr()

sdr.freq_correction = 60
# configure device
sdr.sample_rate = 1e6
sdr.center_freq = 92.3e6
sdr.gain = 128

samples = sdr.read_samples(1024*1024*6)
sdr.close()

Fs = sdr.sample_rate/1e6
Fc = sdr.center_freq/1e6
NFFT = 1024

psd(samples, NFFT=NFFT, Fs=Fs, Fc=Fc)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
show()

# %%
_samples = samples
_samples = _samples - mean(_samples)
psd(_samples, NFFT=NFFT, Fs=Fs, Fc=Fc)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')
show()

# %%
sdr.close()
